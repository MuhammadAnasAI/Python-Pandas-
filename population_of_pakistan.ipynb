# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pakistan.csv')

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
sns.boxplot(df, x= 'PROVINCE', y = 'ALL SEXES (RURAL)')
# Out:
# <Axes: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
df.dtypes
# Out:
# PROVINCE                       object
# DIVISION                       object
# DISTRICT                       object
# SUB DIVISION                   object
# AREA (sq.km)                  float64
# ALL SEXES (RURAL)               int64
# MALE (RURAL)                    int64
# FEMALE (RURAL)                  int64
# TRANSGENDER (RURAL)             int64
# SEX RATIO (RURAL)             float64
# AVG HOUSEHOLD SIZE (RURAL)    float64
# POPULATION 1998 (RURAL)         int64
# ANNUAL GROWTH RATE (RURAL)    float64
# ALL SEXES (URBAN)               int64
# MALE (URBAN)                    int64
# FEMALE (URBAN)                  int64
# TRANSGENDER (URBAN)             int64
# SEX RATIO (URBAN)             float64
# AVG HOUSEHOLD SIZE (URBAN)    float64
# POPULATION 1998 (URBAN)         int64
# ANNUAL GROWTH RATE (URBAN)    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
df.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
sns.boxplot(df, x = 'PROVINCE', y = 'DIVISION', hue = 'DISTRICT')
# Out:
# <Axes: xlabel='PROVINCE', ylabel='DIVISION'>

# %%
df['POPULATION 1998 (RURAL)'].unique()
# Out:
# array([ 407768,  395983,  250959,  297343,  316593,  601406,   62916,
#         314428,  246218,  157049,  385770,  533926,  666127,  710989,
#         613429,  126198,  522388,  438306,  327387,  161010,  485182,
#         369452,  393772,  688771,  842563,   14051,  417338,  314641,
#         197433,  258757,  210354,  236830,  221695,  131485,  900984,
#         924849,  453729,  478372,  200036,  250117,  694457,  321004,
#         377204,  186350,  258335,  494293,   20654,  586535,  253078,
#         390142,  431493,  729885,  611829,  138122,  337482,  268383,
#         250452,  365444,  368235,  342064,  470108,  298539,  482078,
#         534176,  226030,  767868,  523694,  575903,  193356,  519162,
#         182733,  143532,  273036,  330620,  201105,  615443,  137652,
#         133619,  277111,  309073,  180657,  122561,  674097,  224703,
#         565066,  455413,  459047,  320689,  286458,  394565,  332497,
# ...

# %%
df['POPULATION 1998 (RURAL)'].unique().sum()
# Out:
# 88401981

# %%
df['POPULATION 1998 (RURAL)'].value_counts()
# Out:
# POPULATION 1998 (RURAL)
# 0         22
# 407768     1
# 22511      1
# 28867      1
# 108306     1
#           ..
# 135349     1
# 116175     1
# 100466     1
# 188997     1
# 90772      1
# Name: count, Length: 507, dtype: int64

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
df['ALL SEXES (RURAL)'].unique().sum()
# Out:
# 130034790

# %%
#pd.set_option('display.max_rows', None)

# %%
df.groupby('ALL SEXES (RURAL)')['MALE (RURAL)'].mean()
# Out:
# ALL SEXES (RURAL)
# 0                0.0
# 2665          1441.0
# 2868          1447.0
# 5184          2645.0
# 5721          3112.0
# 7583          4032.0
# 7881          4150.0
# 8423          4340.0
# 8584          4334.0
# 9441          4840.0
# 9458          4962.0
# 10217         5435.0
# 10708         5625.0
# 10886         5831.0
# 11730         5990.0
# 11811         6339.0
# 12279         6407.0
# 12952         6627.0
# 13831         7486.0
# 14213         7411.0
# 15345         8720.0
# 15681         8229.0
# 16329         8424.0
# 16646         8967.0
# 16914         8902.0
# 17027         9359.0
# 17465         9848.0
# 18058         9963.0
# 18390         9683.0
# 18452         9615.0
# 18510        10777.0
# 19011         9723.0
# 19497        10583.0
# 20489        10719.0
# 20600        10472.0
# 20768        11575.0
# 20790        10932.0
# 22283        11851.0
# 23215        12661.0
# 23386        12027.0
# 23963        12058.0
# 26155        13441.0
# ...

# %%
df.groupby('ALL SEXES (RURAL)')['FEMALE (RURAL)'].mean()
# Out:
# ALL SEXES (RURAL)
# 0                0.0
# 2665          1223.0
# 2868          1420.0
# 5184          2539.0
# 5721          2609.0
# 7583          3551.0
# 7881          3731.0
# 8423          4083.0
# 8584          4250.0
# 9441          4601.0
# 9458          4495.0
# 10217         4781.0
# 10708         5083.0
# 10886         5055.0
# 11730         5740.0
# 11811         5467.0
# 12279         5872.0
# 12952         6325.0
# 13831         6345.0
# 14213         6802.0
# 15345         6625.0
# 15681         7451.0
# 16329         7905.0
# 16646         7676.0
# 16914         8012.0
# 17027         7668.0
# 17465         7617.0
# 18058         8095.0
# 18390         8704.0
# 18452         8836.0
# 18510         7732.0
# 19011         9287.0
# 19497         8914.0
# 20489         9770.0
# 20600        10128.0
# 20768         9193.0
# 20790         9858.0
# 22283        10432.0
# 23215        10551.0
# 23386        11350.0
# 23963        11905.0
# 26155        12708.0
# ...

# %%
#print(df_male)
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
#print(df_female)
len(df)
# Out:
# 528

# %%
df_2 = df['FEMALE (RURAL)'].sum()

# %%
df_1 = df['MALE (RURAL)'].sum()

# %%
df_delta = df_1 - df_2

# %%
print(df_delta)
# Out:
# 2265932

# %%
df_per = (df_delta / df_1) * 100

# %%
print(df_per)
# Out:
# 3.4256749768688186

# %%
df_per_1 = (df_delta / df_2) * 100

# %%
print(df_per_1)
# Out:
# 3.5471901833622055

# %%
df.groupby(['DIVISION', 'DISTRICT', 'SUB DIVISION'])['ALL SEXES (URBAN)'].mean()
# Out:
# DIVISION                      DISTRICT                      SUB DIVISION
# BAHAWALPUR DIVISION           BAHAWALNAGAR DISTRICT         BAHAWALNAGAR TEHSIL             193840.0
#                                                             CHISHTIAN TEHSIL                149424.0
#                                                             FORT ABBAS TEHSIL                61528.0
#                                                             HAROONABAD TEHSIL               142600.0
#                                                             MINCHINABAD TEHSIL               72294.0
#                               BAHAWALPUR DISTRICT           AHMADPUR EAST TEHSIL            176110.0
#                                                             BAHAWALPUR CITY TEHSIL          682116.0
#                                                             BAHAWALPUR SADDAR TEHSIL        107948.0
# ...

# %%
df.groupby('ALL SEXES (URBAN)').sum()
# Out:
#                                                             PROVINCE  \
# ALL SEXES (URBAN)
# 0                  PUNJABPUNJABSINDHSINDHSINDHSINDHSINDHSINDHBALO...
# 3392                                                     BALOCHISTAN
# 4270                                                           SINDH
# 4364                                                        KPK/FATA
# 5502                                                        KPK/FATA
# 6381                                                           SINDH
# 7484                                                           SINDH
# 7679                                                     BALOCHISTAN
# 7815                                                     BALOCHISTAN
# 9249                                                           SINDH
# 10042                                                    BALOCHISTAN
# 11259                                                    BALOCHISTAN
# ...
